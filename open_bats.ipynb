# %%
import subprocess
import time
import pyautogui
from PIL import ImageGrab
import numpy as np
from dotenv import load_dotenv
import os
import pygetwindow as gw

# %%
load_dotenv()

game_path = os.getenv('GAME_PATH')
dosbox_folder_path = os.getenv('DOSBOX_FOLDER')

# %%
class EliBot:
    def __init__(self, game_path, dosbox_folder_path):

        self.game_path = game_path
        self.dosbox_folder_path = dosbox_folder_path

        """
        Launch game in DOSBox (DOS emulator)
        """
        # Start DOSBox with the game
        self.process = subprocess.Popen(
            self.game_path,
            cwd=self.dosbox_folder_path,
            stdin=subprocess.PIPE
        )
        time.sleep(3)  # Wait for game to load
        
        # Get game window position
        self.find_game_window()
    
    def find_game_window(self):
        """Find DOSBox window coordinates"""
        
        elifoot_windows = [title for title in gw.getAllTitles() if 'ELIFOOT2' in title]
        if len(elifoot_windows) > 1:
            raise ValueError('Multiple Elifoot windows found, exiting')
        if len(elifoot_windows) == 0:
            raise ValueError('No Elifoot window found, exiting')
        windows = gw.getWindowsWithTitle('DOSBox')
        self.windows = windows[0]
        self.game_window.activate()
        
    def capture_screen(self):
        """Capture game screen"""
        if hasattr(self, 'game_window'):
            bbox = (
                self.game_window.left,
                self.game_window.top,
                self.game_window.right,
                self.game_window.bottom
            )
            screenshot = ImageGrab.grab(bbox)
            return np.array(screenshot)
        else:
            # Fallback: capture full screen
            screenshot = ImageGrab.grab()
            return np.array(screenshot)
    
    def analyze_screen(self, screen):
        """Analyze screen to extract game state"""
        # Convert to grayscale for analysis
        from PIL import Image
        img = Image.fromarray(screen)
        gray = img.convert('L')
        
        # Example: Detect health bar by color
        # This depends heavily on your specific game
        
        state = {}
        # Add your analysis logic here
        
        return state


    def send_key(self, key):
        """Send keyboard input to game"""
        print(f">>> Bot pressing: {key}")
        pyautogui.press(key)

    def start_game(self):
        self.send_key('n')
        time.sleep(25)
        self.send_key('G')
        time.sleep(2)
        self.send_key('enter')
        time.sleep(2)
        self.send_key('enter')

    def play(self):
        self.start_game()

# %%
eb = EliBot(game_path, dosbox_folder_path)
eb.play()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 eb = EliBot(game_path, dosbox_folder_path)
#       2 eb.play()
#
# Cell In[3], line 19, in EliBot.__init__(self, game_path, dosbox_folder_path)
#      16 time.sleep(3)  # Wait for game to load
#      18 # Get game window position
# ---> 19 self.find_game_window()
#
# Cell In[3], line 31, in EliBot.find_game_window(self)
#      29 windows = gw.getWindowsWithTitle('DOSBox')
#      30 self.windows = windows[0]
# ---> 31 self.game_window.activate()
#
# AttributeError: 'EliBot' object has no attribute 'game_window'

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %%
bbox = (
    game_window.left,
    game_window.top,
    game_window.right,
    game_window.bottom
    )
screenshot = ImageGrab.grab(bbox)

# %%
from PIL import Image


class EliBot:
    def __init__(self, game_path, dosbox_folder_path):

        self.game_path = game_path
        self.dosbox_folder_path = dosbox_folder_path

        """
        Launch game in DOSBox (DOS emulator)
        """
        # Start DOSBox with the game
        self.process = subprocess.Popen(
            self.game_path,
            cwd=self.dosbox_folder_path,
            stdin=subprocess.PIPE
        )
        time.sleep(3)  # Wait for game to load
        
        # Get game window position
        self.find_game_window()
    
    def find_game_window(self):
        """Find DOSBox window coordinates"""
        
        elifoot_windows = [title for title in gw.getAllTitles() if 'ELIFOOT2' in title]
        if len(elifoot_windows) > 1:
            raise ValueError('Multiple Elifoot windows found, exiting')
        if len(elifoot_windows) == 0:
            raise ValueError('No Elifoot window found, exiting')
        windows = gw.getWindowsWithTitle('DOSBox')
        self.game_window = windows[0]
        self.game_window.activate()
        
    def capture_screen(self):
        """Capture game screen"""
        if hasattr(self, 'game_window'):
            bbox = (
                self.game_window.left,
                self.game_window.top,
                self.game_window.right,
                self.game_window.bottom
            )
            screenshot = ImageGrab.grab(bbox)
            return np.array(screenshot)
        else:
            # Fallback: capture full screen
            screenshot = ImageGrab.grab()
            return np.array(screenshot)
    
    def analyze_screen(self, screen):
        """Analyze screen to extract game state"""
        # Convert to grayscale for analysis
        from PIL import Image
        img = Image.fromarray(screen)
        gray = img.convert('L')
        
        # Example: Detect health bar by color
        # This depends heavily on your specific game
        
        state = {}
        # Add your analysis logic here
        
        return state


    def send_key(self, key):
        """Send keyboard input to game"""
        print(f">>> Bot pressing: {key}")
        pyautogui.press(key)

    def start_game(self):
        self.send_key('n')
        time.sleep(25)
        self.send_key('G')
        time.sleep(2)
        self.send_key('enter')
        time.sleep(2)
        self.send_key('enter')

    def try_enter(self):
        time.sleep(5)
        self.send_key('enter')

    def try_f(self):
        time.sleep(5)
        self.send_key('f1')
        self.send_key('f3')
        self.send_key('f6')
        self.send_key('f8')
        

    def try_n(self):
        time.sleep(5)
        self.send_key('n')


    def try_esc(self):
        time.sleep(5)
        self.send_key('esc')



    def play(self):
        self.start_game()
        counter = 0
        while True:
            self.try_enter()
            screen = self.capture_screen()
            screen = Image.fromarray(screen)
            screen.save("{}_enter.jpeg".format(counter))

            self.try_f()
            screen = self.capture_screen()
            screen = Image.fromarray(screen)
            screen.save("{}_f.jpeg".format(counter))

            self.try_esc()
            self.try_esc()
            screen = self.capture_screen()
            screen = Image.fromarray(screen)
            screen.save("{}_esc_esc.jpeg".format(counter))

            self.try_n()
            screen = self.capture_screen()
            screen = Image.fromarray(screen)
            screen.save("{}_no.jpeg".format(counter))

            counter += 1

# %%
eb = EliBot(game_path, dosbox_folder_path)
eb.play()
# Out:
# >>> Bot pressing: n
# >>> Bot pressing: G
# >>> Bot pressing: enter
# >>> Bot pressing: enter
# >>> Bot pressing: enter
# >>> Bot pressing: f1
# >>> Bot pressing: f3
# >>> Bot pressing: f6
# >>> Bot pressing: f8
# >>> Bot pressing: esc
# >>> Bot pressing: esc
# >>> Bot pressing: n
# >>> Bot pressing: enter
# >>> Bot pressing: f1
# >>> Bot pressing: f3
# >>> Bot pressing: f6
# >>> Bot pressing: f8
# >>> Bot pressing: esc
# >>> Bot pressing: esc
# >>> Bot pressing: n
# >>> Bot pressing: enter
# >>> Bot pressing: f1
# >>> Bot pressing: f3
# >>> Bot pressing: f6
# >>> Bot pressing: f8
# >>> Bot pressing: esc
# >>> Bot pressing: esc
# >>> Bot pressing: n
# >>> Bot pressing: enter
# >>> Bot pressing: f1
# >>> Bot pressing: f3
# >>> Bot pressing: f6
# >>> Bot pressing: f8
# >>> Bot pressing: esc
# >>> Bot pressing: esc
# >>> Bot pressing: n
# >>> Bot pressing: enter
# >>> Bot pressing: f1
# >>> Bot pressing: f3
# >>> Bot pressing: f6
# >>> Bot pressing: f8
# >>> Bot pressing: esc
# >>> Bot pressing: esc
# >>> Bot pressing: n
# >>> Bot pressing: enter
# >>> Bot pressing: f1
# >>> Bot pressing: f3
# >>> Bot pressing: f6
# >>> Bot pressing: f8
# >>> Bot pressing: esc
# >>> Bot pressing: esc
# >>> Bot pressing: n
# >>> Bot pressing: enter
# >>> Bot pressing: f1
# >>> Bot pressing: f3
# >>> Bot pressing: f6
# >>> Bot pressing: f8
# ---------------------------------------------------------------------------
# PyGetWindowException                      Traceback (most recent call last)
# Cell In[9], line 2
#       1 eb = EliBot(game_path, dosbox_folder_path)
# ----> 2 eb.play()
#
# Cell In[8], line 115, in EliBot.play(self)
#     112 screen.save("{}_enter.jpeg".format(counter))
#     114 self.try_f()
# --> 115 screen = self.capture_screen()
#     116 screen = Image.fromarray(screen)
#     117 screen.save("{}_f.jpeg".format(counter))
#
# Cell In[8], line 40, in EliBot.capture_screen(self)
#      37 """Capture game screen"""
#      38 if hasattr(self, 'game_window'):
#      39     bbox = (
# ---> 40         self.game_window.left,
#      41         self.game_window.top,
#      42         self.game_window.right,
#      43         self.game_window.bottom
#      44     )
#      45     screenshot = ImageGrab.grab(bbox)
#      46     return np.array(screenshot)
#
# File c:\Users\guilh\Git\Elifoot\.venv\Lib\site-packages\pygetwindow\__init__.py:149, in BaseWindow.left(self)
#     147 @property
#     148 def left(self):
# --> 149     return self._rect.left
#
# File c:\Users\guilh\Git\Elifoot\.venv\Lib\site-packages\pyrect\__init__.py:296, in Rect.left(self)
#     285 """
#     286 The x coordinate for the left edge of the rectangle. `x` is an alias for `left`.
#     287
#    (...)    293 Rect(left=50, top=0, width=10, height=20)
#     294 """
#     295 if self.onRead is not None:
# --> 296     self.onRead(LEFT)
#     297 return self._left
#
# File c:\Users\guilh\Git\Elifoot\.venv\Lib\site-packages\pygetwindow\__init__.py:54, in BaseWindow._setupRectProperties.<locals>._onRead(attrName)
#      53 def _onRead(attrName):
# ---> 54     r = self._getWindowRect()
#      55     self._rect._left = r.left  # Setting _left directly to skip the onRead.
#      56     self._rect._top = r.top  # Setting _top directly to skip the onRead.
#
# File c:\Users\guilh\Git\Elifoot\.venv\Lib\site-packages\pygetwindow\_pygetwindow_win.py:199, in Win32Window._getWindowRect(self)
#     197     return Rect(rect.left, rect.top, rect.right, rect.bottom)
#     198 else:
# --> 199     _raiseWithLastError()
#
# File c:\Users\guilh\Git\Elifoot\.venv\Lib\site-packages\pygetwindow\_pygetwindow_win.py:99, in _raiseWithLastError()
#      96 """A helper function that raises PyGetWindowException using the error
#      97 information from GetLastError() and FormatMessage()."""
#      98 errorCode = ctypes.windll.kernel32.GetLastError()
# ---> 99 raise PyGetWindowException('Error code from Windows: %s - %s' % (errorCode, _formatMessage(errorCode)))
#
# PyGetWindowException: Error code from Windows: 1400 - Invalid window handle.
